# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
from citipy import citipy
# Import linregress
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a91a7d6477d21bc16a0428f942552fb4

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 34.02,
#   'feels_like': 26.06,
#   'temp_min': 29.3,
#   'temp_max': 37.22,
#   'pressure': 1016,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 10.36, 'deg': 210},
#  'clouds': {'all': 20},
#  'dt': 1644459393,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1644407328,
#   'sunset': 1644444494},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data["weather"][0]["description"]
# Out:
# 'few clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_description = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"Current Description": city_description,
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | jalingo
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | lashio
# Processing Record 6 of Set 1 | hovd
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | touros
# Processing Record 10 of Set 1 | mamallapuram
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kirakira
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 1 | komsomolskiy
# Processing Record 22 of Set 1 | barinas
# Processing Record 23 of Set 1 | orsha
# Processing Record 24 of Set 1 | wuzhou
# Processing Record 25 of Set 1 | hambantota
# Processing Record 26 of Set 1 | luderitz
# Processing Record 27 of Set 1 | plessisville
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | oconomowoc
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | balad
# Processing Record 32 of Set 1 | ayan
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | beloha
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | san francisco
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | burica
# City not found. Skipping...
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | port augusta
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | mabaruma
# Processing Record 43 of Set 1 | yerbogachen
# Processing Record 44 of Set 1 | gat
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | dingle
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 1 | cozumel
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | elko
# Processing Record 9 of Set 2 | sola
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | kargasok
# Processing Record 14 of Set 2 | bethanien
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | ayabaca
# Processing Record 17 of Set 2 | afsin
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | ipixuna
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | tuatapere
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | pauini
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | ahipara
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | gotsu
# Processing Record 32 of Set 2 | christchurch
# Processing Record 33 of Set 2 | sabang
# Processing Record 34 of Set 2 | seoul
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | kununurra
# Processing Record 38 of Set 2 | klaksvik
# Processing Record 39 of Set 2 | tabou
# Processing Record 40 of Set 2 | kandy
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | bodden town
# Processing Record 43 of Set 2 | dubbo
# Processing Record 44 of Set 2 | togur
# Processing Record 45 of Set 2 | ocseny
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 3 | umiray
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | aras
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | morant bay
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | ketou
# Processing Record 11 of Set 3 | champagnole
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | chone
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | north platte
# Processing Record 17 of Set 3 | bud
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | ketchikan
# Processing Record 20 of Set 3 | teya
# Processing Record 21 of Set 3 | barra patuca
# Processing Record 22 of Set 3 | porosozero
# Processing Record 23 of Set 3 | salalah
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | katsuura
# Processing Record 28 of Set 3 | matagami
# Processing Record 29 of Set 3 | pochutla
# Processing Record 30 of Set 3 | roma
# Processing Record 31 of Set 3 | cacapava
# Processing Record 32 of Set 3 | ekhabi
# Processing Record 33 of Set 3 | jasper
# Processing Record 34 of Set 3 | quatre cocos
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | buta
# Processing Record 39 of Set 3 | igarape-miri
# City not found. Skipping...
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | huambo
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | ormara
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | longyearbyen
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | salta
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | mikkeli
# Processing Record 1 of Set 4 | sidney
# Processing Record 2 of Set 4 | shwebo
# Processing Record 3 of Set 4 | tiznit
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | slave lake
# Processing Record 6 of Set 4 | port macquarie
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | fuling
# Processing Record 10 of Set 4 | sisophon
# Processing Record 11 of Set 4 | bilma
# Processing Record 12 of Set 4 | jaipur hat
# City not found. Skipping...
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | gazojak
# Processing Record 15 of Set 4 | batagay-alyta
# Processing Record 16 of Set 4 | turukhansk
# Processing Record 17 of Set 4 | terme
# Processing Record 18 of Set 4 | handia
# Processing Record 19 of Set 4 | rantepao
# Processing Record 20 of Set 4 | independence
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | sorland
# Processing Record 23 of Set 4 | klyuchi
# Processing Record 24 of Set 4 | vung tau
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 4 | muros
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | clyde river
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | palmas
# Processing Record 33 of Set 4 | rawson
# Processing Record 34 of Set 4 | pecos
# Processing Record 35 of Set 4 | kasongo-lunda
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | lagos
# Processing Record 38 of Set 4 | tevaitoa
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | obo
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | grindavik
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | impfondo
# Processing Record 46 of Set 4 | biak
# Processing Record 47 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 4 | nome
# Processing Record 49 of Set 4 | shakiso
# Processing Record 50 of Set 4 | bereznik
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | prince rupert
# Processing Record 4 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 5 | balikpapan
# Processing Record 6 of Set 5 | champerico
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | husavik
# Processing Record 10 of Set 5 | san carlos
# Processing Record 11 of Set 5 | waipawa
# Processing Record 12 of Set 5 | grants pass
# Processing Record 13 of Set 5 | rorvik
# Processing Record 14 of Set 5 | mersing
# Processing Record 15 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | sao filipe
# Processing Record 18 of Set 5 | chirongui
# Processing Record 19 of Set 5 | portknockie
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | kaseda
# Processing Record 23 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 24 of Set 5 | inuvik
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | lakatoro
# Processing Record 28 of Set 5 | grand-santi
# Processing Record 29 of Set 5 | olafsvik
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | bethel
# Processing Record 32 of Set 5 | alofi
# Processing Record 33 of Set 5 | bartica
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | charters towers
# Processing Record 36 of Set 5 | comodoro rivadavia
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | tongzi
# Processing Record 39 of Set 5 | ornskoldsvik
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | cukai
# Processing Record 42 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | waingapu
# Processing Record 45 of Set 5 | skiros
# City not found. Skipping...
# Processing Record 46 of Set 5 | baglung
# Processing Record 47 of Set 5 | kuito
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | alice springs
# Processing Record 50 of Set 5 | abu kamal
# Processing Record 1 of Set 6 | wattegama
# Processing Record 2 of Set 6 | karratha
# Processing Record 3 of Set 6 | young
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | meadow lake
# Processing Record 6 of Set 6 | kysyl-syr
# Processing Record 7 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 6 | san felipe
# Processing Record 9 of Set 6 | qui nhon
# Processing Record 10 of Set 6 | petropavl
# Processing Record 11 of Set 6 | praia
# Processing Record 12 of Set 6 | altay
# Processing Record 13 of Set 6 | rundu
# Processing Record 14 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 6 | nautla
# Processing Record 16 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 6 | phan thiet
# Processing Record 18 of Set 6 | kuusamo
# Processing Record 19 of Set 6 | belyy yar
# Processing Record 20 of Set 6 | novorzhev
# Processing Record 21 of Set 6 | port hedland
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | ngunguru
# Processing Record 24 of Set 6 | general roca
# Processing Record 25 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 6 | niquero
# Processing Record 27 of Set 6 | santa ana
# Processing Record 28 of Set 6 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 29 of Set 6 | yumen
# Processing Record 30 of Set 6 | flinders
# Processing Record 31 of Set 6 | marinette
# Processing Record 32 of Set 6 | sao lourenco do sul
# Processing Record 33 of Set 6 | dukat
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | labuhan
# Processing Record 36 of Set 6 | pisco
# Processing Record 37 of Set 6 | huangchuan
# Processing Record 38 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 39 of Set 6 | diego de almagro
# Processing Record 40 of Set 6 | deyang
# Processing Record 41 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | songkhla
# Processing Record 44 of Set 6 | san matias
# Processing Record 45 of Set 6 | mandalgovi
# Processing Record 46 of Set 6 | hithadhoo
# Processing Record 47 of Set 6 | sao joao da barra
# Processing Record 48 of Set 6 | puerto montt
# Processing Record 49 of Set 6 | belmonte
# Processing Record 50 of Set 6 | natchez
# Processing Record 1 of Set 7 | shangrao
# Processing Record 2 of Set 7 | ishigaki
# Processing Record 3 of Set 7 | vila velha
# Processing Record 4 of Set 7 | qasigiannguit
# Processing Record 5 of Set 7 | det udom
# Processing Record 6 of Set 7 | paranaiba
# Processing Record 7 of Set 7 | thunder bay
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | panguna
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | saint anthony
# Processing Record 12 of Set 7 | byron bay
# Processing Record 13 of Set 7 | ruteng
# Processing Record 14 of Set 7 | sibolga
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | ploemeur
# Processing Record 17 of Set 7 | bandarbeyla
# Processing Record 18 of Set 7 | deputatskiy
# Processing Record 19 of Set 7 | aswan
# Processing Record 20 of Set 7 | andenes
# Processing Record 21 of Set 7 | hobyo
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | mae hong son
# Processing Record 24 of Set 7 | urucara
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | tual
# Processing Record 27 of Set 7 | mandera
# Processing Record 28 of Set 7 | rassvet
# Processing Record 29 of Set 7 | sur
# Processing Record 30 of Set 7 | maidens
# Processing Record 31 of Set 7 | hue
# Processing Record 32 of Set 7 | luganville
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | panuco
# Processing Record 35 of Set 7 | wukari
# Processing Record 36 of Set 7 | bosobolo
# Processing Record 37 of Set 7 | mafinga
# Processing Record 38 of Set 7 | alta
# Processing Record 39 of Set 7 | aquin
# Processing Record 40 of Set 7 | rumphi
# Processing Record 41 of Set 7 | narsaq
# Processing Record 42 of Set 7 | swift current
# Processing Record 43 of Set 7 | victoriaville
# Processing Record 44 of Set 7 | bengkulu
# Processing Record 45 of Set 7 | chokurdakh
# Processing Record 46 of Set 7 | karasjok
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | mariakani
# Processing Record 49 of Set 7 | broken hill
# Processing Record 50 of Set 7 | haag
# Processing Record 1 of Set 8 | sarh
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | lakes entrance
# Processing Record 4 of Set 8 | port-gentil
# Processing Record 5 of Set 8 | rossosh
# Processing Record 6 of Set 8 | port blair
# Processing Record 7 of Set 8 | maunabo
# Processing Record 8 of Set 8 | ola
# Processing Record 9 of Set 8 | gadsden
# Processing Record 10 of Set 8 | luebo
# Processing Record 11 of Set 8 | kaihua
# Processing Record 12 of Set 8 | zemio
# Processing Record 13 of Set 8 | bautzen
# Processing Record 14 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 8 | disna
# Processing Record 16 of Set 8 | ballina
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | lima
# Processing Record 19 of Set 8 | chengde
# Processing Record 20 of Set 8 | tashir
# Processing Record 21 of Set 8 | athabasca
# Processing Record 22 of Set 8 | shiojiri
# Processing Record 23 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 8 | birecik
# Processing Record 25 of Set 8 | ramshir
# Processing Record 26 of Set 8 | tigzirt
# Processing Record 27 of Set 8 | aguimes
# Processing Record 28 of Set 8 | sao miguel do araguaia
# Processing Record 29 of Set 8 | hirara
# Processing Record 30 of Set 8 | wad madani
# Processing Record 31 of Set 8 | maldonado
# Processing Record 32 of Set 8 | victoria
# Processing Record 33 of Set 8 | puerto leguizamo
# Processing Record 34 of Set 8 | nemuro
# Processing Record 35 of Set 8 | itoman
# Processing Record 36 of Set 8 | coro
# Processing Record 37 of Set 8 | cazones
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | auki
# Processing Record 40 of Set 8 | haines junction
# Processing Record 41 of Set 8 | bahawalnagar
# Processing Record 42 of Set 8 | tessalit
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | ambilobe
# Processing Record 45 of Set 8 | lasa
# Processing Record 46 of Set 8 | skibbereen
# Processing Record 47 of Set 8 | nizhnyaya omka
# Processing Record 48 of Set 8 | chumikan
# Processing Record 49 of Set 8 | alghero
# Processing Record 50 of Set 8 | marsh harbour
# Processing Record 1 of Set 9 | orlik
# Processing Record 2 of Set 9 | hennebont
# Processing Record 3 of Set 9 | dagua
# Processing Record 4 of Set 9 | burnie
# Processing Record 5 of Set 9 | abashiri
# Processing Record 6 of Set 9 | meulaboh
# Processing Record 7 of Set 9 | bulawayo
# Processing Record 8 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 9 of Set 9 | mount isa
# Processing Record 10 of Set 9 | hamilton
# Processing Record 11 of Set 9 | fairbanks
# Processing Record 12 of Set 9 | manadhoo
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | doha
# Processing Record 16 of Set 9 | polson
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | banki
# Processing Record 19 of Set 9 | roald
# Processing Record 20 of Set 9 | kailua
# Processing Record 21 of Set 9 | nizhniy tsasuchey
# Processing Record 22 of Set 9 | tura
# Processing Record 23 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 9 | birao
# Processing Record 25 of Set 9 | piryion
# City not found. Skipping...
# Processing Record 26 of Set 9 | gaoual
# Processing Record 27 of Set 9 | shahr-e babak
# Processing Record 28 of Set 9 | olavarria
# Processing Record 29 of Set 9 | mimongo
# Processing Record 30 of Set 9 | maxixe
# Processing Record 31 of Set 9 | skjervoy
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | puerto madryn
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | asau
# Processing Record 36 of Set 9 | talcahuano
# Processing Record 37 of Set 9 | surt
# Processing Record 38 of Set 9 | shieli
# Processing Record 39 of Set 9 | rodbyhavn
# Processing Record 40 of Set 9 | praia da vitoria
# Processing Record 41 of Set 9 | viedma
# Processing Record 42 of Set 9 | khanino
# Processing Record 43 of Set 9 | mayfield
# Processing Record 44 of Set 9 | encruzilhada do sul
# Processing Record 45 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | cacule
# Processing Record 47 of Set 9 | maniitsoq
# Processing Record 48 of Set 9 | guadalupe y calvo
# Processing Record 49 of Set 9 | dunedin
# Processing Record 50 of Set 9 | panaba
# Processing Record 1 of Set 10 | melville
# Processing Record 2 of Set 10 | stornoway
# Processing Record 3 of Set 10 | berlevag
# Processing Record 4 of Set 10 | ranong
# Processing Record 5 of Set 10 | kovernino
# Processing Record 6 of Set 10 | smithers
# Processing Record 7 of Set 10 | necochea
# Processing Record 8 of Set 10 | yaan
# Processing Record 9 of Set 10 | porto belo
# Processing Record 10 of Set 10 | abu samrah
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | solnechnyy
# Processing Record 13 of Set 10 | ust-barguzin
# Processing Record 14 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | dzerzhinsk
# Processing Record 16 of Set 10 | krugersdorp
# Processing Record 17 of Set 10 | arlit
# Processing Record 18 of Set 10 | faanui
# Processing Record 19 of Set 10 | gondanglegi
# Processing Record 20 of Set 10 | xining
# Processing Record 21 of Set 10 | beroroha
# Processing Record 22 of Set 10 | nibbar
# Processing Record 23 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 10 | sao gotardo
# Processing Record 25 of Set 10 | zhezkazgan
# Processing Record 26 of Set 10 | isangel
# Processing Record 27 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 10 | boa vista
# Processing Record 29 of Set 10 | mastic beach
# Processing Record 30 of Set 10 | bilibino
# Processing Record 31 of Set 10 | elk plain
# Processing Record 32 of Set 10 | xuddur
# Processing Record 33 of Set 10 | ternate
# Processing Record 34 of Set 10 | puerto madero
# Processing Record 35 of Set 10 | jiazi
# Processing Record 36 of Set 10 | kati
# Processing Record 37 of Set 10 | nanortalik
# Processing Record 38 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 10 | betioky
# Processing Record 40 of Set 10 | kuchera
# Processing Record 41 of Set 10 | manuk mangkaw
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | flin flon
# Processing Record 44 of Set 10 | ayutla
# Processing Record 45 of Set 10 | bonthe
# Processing Record 46 of Set 10 | robe
# Processing Record 47 of Set 10 | coronado
# Processing Record 48 of Set 10 | nelson bay
# Processing Record 49 of Set 10 | yuryevets
# Processing Record 50 of Set 10 | verkhoyansk
# Processing Record 1 of Set 11 | el tocuyo
# Processing Record 2 of Set 11 | honningsvag
# Processing Record 3 of Set 11 | khorixas
# Processing Record 4 of Set 11 | lata
# Processing Record 5 of Set 11 | balkanabat
# Processing Record 6 of Set 11 | los llanos de aridane
# Processing Record 7 of Set 11 | kenora
# Processing Record 8 of Set 11 | arman
# Processing Record 9 of Set 11 | jaunjelgava
# Processing Record 10 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | matay
# Processing Record 13 of Set 11 | dorsten
# Processing Record 14 of Set 11 | stephenville crossing
# Processing Record 15 of Set 11 | kuching
# Processing Record 16 of Set 11 | viseu
# Processing Record 17 of Set 11 | paamiut
# Processing Record 18 of Set 11 | tarauaca
# Processing Record 19 of Set 11 | chute-aux-outardes
# Processing Record 20 of Set 11 | kedrovyy
# Processing Record 21 of Set 11 | boddam
# Processing Record 22 of Set 11 | honiara
# Processing Record 23 of Set 11 | a
# City not found. Skipping...
# Processing Record 24 of Set 11 | puerto escondido
# Processing Record 25 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 11 | tarata
# Processing Record 27 of Set 11 | sadowara
# City not found. Skipping...
# Processing Record 28 of Set 11 | killybegs
# Processing Record 29 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 30 of Set 11 | iquitos
# Processing Record 31 of Set 11 | lillooet
# Processing Record 32 of Set 11 | san rafael del sur
# Processing Record 33 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 11 | andra
# Processing Record 35 of Set 11 | loikaw
# Processing Record 36 of Set 11 | nuuk
# Processing Record 37 of Set 11 | zhangjiakou
# Processing Record 38 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | okha
# Processing Record 40 of Set 11 | altar
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | chernyshevskiy
# Processing Record 43 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 11 | tamandare
# Processing Record 45 of Set 11 | zeya
# Processing Record 46 of Set 11 | beisfjord
# Processing Record 47 of Set 11 | broome
# Processing Record 48 of Set 11 | tilichiki
# Processing Record 49 of Set 11 | yulara
# Processing Record 50 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 12 | te anau
# Processing Record 2 of Set 12 | lafiagi
# Processing Record 3 of Set 12 | mixtepec
# City not found. Skipping...
# Processing Record 4 of Set 12 | burns lake
# Processing Record 5 of Set 12 | nantucket
# Processing Record 6 of Set 12 | koplik
# Processing Record 7 of Set 12 | chincha alta
# Processing Record 8 of Set 12 | humberto de campos
# Processing Record 9 of Set 12 | santa cruz
# Processing Record 10 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 11 of Set 12 | sergeyevka
# Processing Record 12 of Set 12 | trelew
# Processing Record 13 of Set 12 | jiuquan
# Processing Record 14 of Set 12 | manor
# Processing Record 15 of Set 12 | utmanzai
# Processing Record 16 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 12 | bebra
# Processing Record 18 of Set 12 | camacha
# Processing Record 19 of Set 12 | havre-saint-pierre
# Processing Record 20 of Set 12 | pathein
# Processing Record 21 of Set 12 | capreol
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | saint-pierre
# Processing Record 24 of Set 12 | halifax
# Processing Record 25 of Set 12 | muisne
# Processing Record 26 of Set 12 | palana
# Processing Record 27 of Set 12 | pearl
# Processing Record 28 of Set 12 | mukhen
# Processing Record 29 of Set 12 | bima
# Processing Record 30 of Set 12 | mulege
# Processing Record 31 of Set 12 | chapleau
# Processing Record 32 of Set 12 | sri aman
# Processing Record 33 of Set 12 | bathurst
# Processing Record 34 of Set 12 | jojoima
# Processing Record 35 of Set 12 | northam
# Processing Record 36 of Set 12 | kazerun
# Processing Record 37 of Set 12 | adelaide
# Processing Record 38 of Set 12 | ushtobe
# Processing Record 39 of Set 12 | ixtapa
# Processing Record 40 of Set 12 | awbari
# Processing Record 41 of Set 12 | garissa
# Processing Record 42 of Set 12 | dalhousie
# Processing Record 43 of Set 12 | portree
# Processing Record 44 of Set 12 | pamanukan
# Processing Record 45 of Set 12 | inirida
# Processing Record 46 of Set 12 | atasu
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | sabratah
# Processing Record 49 of Set 12 | chengdu
# Processing Record 50 of Set 12 | allentown
# Processing Record 1 of Set 13 | faya
# Processing Record 2 of Set 13 | majene
# Processing Record 3 of Set 13 | harrisonburg
# Processing Record 4 of Set 13 | rohru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#   Current Description          City      Lat       Lng  Max Temp  Humidity  \
# 0          light snow        Barrow  71.2906 -156.7887    -20.18        69
# 1     overcast clouds    Bredasdorp -34.5322   20.0403     62.28        83
# 2       broken clouds       Jalingo   8.8833   11.3667     72.00        16
# 3     overcast clouds        Albany  42.6001  -73.9662     40.68        68
# 4           clear sky        Lashio  22.9333   97.7500     64.18        41
# 5     overcast clouds          Hovd  48.0056   91.6419     -4.56        92
# 6       moderate rain        Hasaki  35.7333  140.8333     41.40        83
# 7     overcast clouds        Touros  -5.1989  -35.4608     79.70        72
# 8    scattered clouds  Mamallapuram  12.6264   80.1722     78.85        65
# 9       broken clouds     Jamestown  42.0970  -79.2353     43.92        40
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100       10.36      US  2022-02-10 03:22:52
# 1         100        6.46      ZA  2022-02-10 03:18:35
# 2          78        5.32      NG  2022-02-10 03:22:53
# 3          99        2.93      US  2022-02-10 03:19:46
# 4           3        1.16      MM  2022-02-10 03:22:53
# 5          99        0.07      MN  2022-02-10 03:21:13
# 6         100       17.49      JP  2022-02-10 03:22:53
# 7          85        8.34      BR  2022-02-10 03:22:54
# 8          41        8.16      IN  2022-02-10 03:22:54
# 9          75       12.66      US  2022-02-10 03:22:54

# %%
city_data_df_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[city_data_df_reorder]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow      US  71.2906 -156.7887    -20.18        69         100
# 1      Bredasdorp      ZA -34.5322   20.0403     62.28        83         100
# 2         Jalingo      NG   8.8833   11.3667     72.00        16          78
# 3          Albany      US  42.6001  -73.9662     40.68        68          99
# 4          Lashio      MM  22.9333   97.7500     64.18        41           3
# ..            ...     ...      ...       ...       ...       ...         ...
# 546     Allentown      US  40.6084  -75.4902     41.94        75           0
# 547          Faya      SA  18.3851   42.4509     55.51        74           9
# 548        Majene      ID  -3.5403  118.9707     77.32        90         100
# 549  Harrisonburg      US  38.4496  -78.8689     41.23        79         100
# 550         Rohru      IN  31.2167   77.7500     39.69        50           0
#
#      Wind Speed Current Description
# 0         10.36          light snow
# 1          6.46     overcast clouds
# 2          5.32       broken clouds
# 3          2.93     overcast clouds
# 4          1.16           clear sky
# ..          ...                 ...
# 546        5.75           clear sky
# 547        2.59           clear sky
# 548        8.01          light rain
# 549        4.61     overcast clouds
# 550        4.36           clear sky
#
# [551 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
